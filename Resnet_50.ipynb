# %% [markdown]
# <a href="https://colab.research.google.com/github/aneekbsws/Convolutional-Neural-Networks/blob/main/Resnet_50.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import h5py
import matplotlib.pyplot as plt

# %% [markdown]
# #Identity Block#
# Identity block is a basic set of three blocks and a residual block.

# %%
from tensorflow.keras.initializers import random_uniform

# %%
def identity_block(X, f, filters, training=True, initializer=random_uniform):
  F1, F2, F3 = filters # filters is a tuple containing number of filters of the three layers in main path
  X_short = X

  #1st layer = 1x1 convolution
  X = tf.keras.layers.Conv2D(filters=F1, kernel_size=1, strides=(1,1), padding='valid', kernel_initializer=initializer(seed=0))(X)
  X = tf.keras.layers.BatchNormalization(axis=3)(X, training=training)
  X = tf.keras.layers.Activation(activation='relu')(X)

  #Middle layer - fxf convolution with same padding
  X = tf.keras.layers.Conv2D(filters=F2, kernel_size=(f,f), strides=(1,1), padding='same', kernel_initializer=initializer(seed=0))(X)
  X = tf.keras.layers.BatchNormalization(axis=3)(X, training=training)
  X = tf.keras.layers.Activation(activation='relu')(X)

  #last layer - 1x1 convolutio
  X = tf.keras.layers.Conv2D(filters=F3, kernel_size=1, strides=(1,1), padding='valid', kernel_initializer=initializer(seed=0))(X)
  X = tf.keras.layers.BatchNormalization(axis=3)(X, training=training)

  #Add shortcut layer before activation function
  X = tf.keras.layers.Add()([X, X_short])

  #Finally apply activation function
  X = tf.keras.layers.Activation(activation='relu')(X)

  return X

# %%
from tensorflow.keras.initializers import glorot_uniform

# %%
def conv_block(X,f,filters, s=2,training=True, initializer=glorot_uniform):
  F1,F2,F3 = filters
  # print(F1)
  # print(F2)
  # print(F3)
  print(filters)
  X_short = X

  #1st layer = 1x1 convolution, stride = 2
  X = tf.keras.layers.Conv2D(F1, kernel_size=1, strides=(s,s), padding='valid', kernel_initializer=initializer(seed=0))(X) # Will use 
  X = tf.keras.layers.BatchNormalization(axis=3)(X, training=training)
  X = tf.keras.layers.Activation(activation='relu')(X)

  #Middle layer - fxf convolution with same padding
  X = tf.keras.layers.Conv2D(F2, kernel_size=(f,f), strides=(1,1), padding='same', kernel_initializer=initializer(seed=0))(X)
  X = tf.keras.layers.BatchNormalization(axis=3)(X, training=training)
  X = tf.keras.layers.Activation(activation='relu')(X)

  #last layer - 1x1 convolution
  X = tf.keras.layers.Conv2D(F3, kernel_size=1, strides=(1,1), padding='valid', kernel_initializer=initializer(seed=0))(X)
  X = tf.keras.layers.BatchNormalization(axis=3)(X, training=training)

  #Shortcut layer - 1x1 convolution, strides = 2
  X_short = tf.keras.layers.Conv2D(filters=F3, kernel_size=1, strides=(s,s), padding='valid', kernel_initializer=initializer(seed=0))(X_short)
  X_short = tf.keras.layers.BatchNormalization(axis=3)(X_short, training=training) 

  #Adding them
  X = tf.keras.layers.Add()([X, X_short])
  X = tf.keras.layers.Activation(activation='relu')(X)

  return X

# %%
from tensorflow.keras.initializers import glorot_uniform

# %%
def resnet_50(input_shape=(64,64,3), classes=6):
  X_input = tf.keras.layers.Input(input_shape)
  X = tf.keras.layers.ZeroPadding2D((3,3))(X_input)

  #Stage 1 -> CONV2D -> BATCHNORM -> RELU -> MaxPooL
  X = tf.keras.layers.Conv2D(64, kernel_size=(7,7), strides=(2,2), kernel_initializer=glorot_uniform(seed=0))(X)
  X = tf.keras.layers.BatchNormalization(axis=3)(X)
  X = tf.keras.layers.Activation(activation='relu')(X)
  X = tf.keras.layers.MaxPool2D(pool_size=(3,3), strides=(2,2))(X)

  #Stage-2 -> CONVPOOL -> ID BLOCK*2
  X = conv_block(X, f=3, filters=[64,64,256],s=1)
  X = identity_block(X, 3, [64,64,256])
  X = identity_block(X, 3, [64,64,256])
  #print(X.element_spec)

  #Stage-3 -> CONVPOOL -> ID BLOCK*3
  X = conv_block(X, f=3, filters=[128,128,512],s=2)
  X = identity_block(X, 3, [128,128,512])
  X = identity_block(X, 3, [128,128,512])
  X = identity_block(X, 3, [128,128,512])
  #print(X.element_spec)

  #Stage-4 -> CONVPOOL -> ID-BLOCK*5
  X = conv_block(X, f=3, filters=[256,256,1024],s=2)
  X = identity_block(X, 3, [256,256,1024])
  X = identity_block(X, 3, [256,256,1024])
  X = identity_block(X, 3, [256,256,1024])
  X = identity_block(X, 3, [256,256,1024])
  X = identity_block(X, 3, [256,256,1024])

  #Stage-5 -> CONVPOOL -> ID-BLOCK*2
  X = conv_block(X, f=3, filters=[512,512,2048],s=2)
  X = identity_block(X, 3, [512,512,2048])
  X = identity_block(X, 3, [512,512,2048])

  # Stage-6 -> AVGPOOL -> FLATTEN -> FC
  X = tf.keras.layers.AveragePooling2D(pool_size=(2,2), strides=2)(X)
  X = tf.keras.layers.Flatten()(X)
  X = tf.keras.layers.Dense(units = classes, activation='softmax', kernel_initializer=glorot_uniform(seed=0))(X)

  # Create the model
  model = tf.keras.Model(inputs=X_input, outputs=X)

  return model

# %%
model = resnet_50(input_shape=(64,64,3), classes=6)
# Out:
# [64, 64, 256]
# [128, 128, 512]
# [256, 256, 1024]
# [512, 512, 2048]

# %%
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_25 (InputLayer)          [(None, 64, 64, 3)]  0           []
#
#  zero_padding2d_22 (ZeroPadding  (None, 70, 70, 3)   0           ['input_25[0][0]']
#  2D)
#
#  conv2d_231 (Conv2D)            (None, 32, 32, 64)   9472        ['zero_padding2d_22[0][0]']
#
#  batch_normalization_230 (Batch  (None, 32, 32, 64)  256         ['conv2d_231[0][0]']
#  Normalization)
#
#  activation_196 (Activation)    (None, 32, 32, 64)   0           ['batch_normalization_230[0][0]']
#
#  max_pooling2d_22 (MaxPooling2D  (None, 15, 15, 64)  0           ['activation_196[0][0]']
#  )
#
#  conv2d_232 (Conv2D)            (None, 15, 15, 64)   4160        ['max_pooling2d_22[0][0]']
#
#  batch_normalization_231 (Batch  (None, 15, 15, 64)  256         ['conv2d_232[0][0]']
#  Normalization)
#
#  activation_197 (Activation)    (None, 15, 15, 64)   0           ['batch_normalization_231[0][0]']
#
#  conv2d_233 (Conv2D)            (None, 15, 15, 64)   36928       ['activation_197[0][0]']
#
#  batch_normalization_232 (Batch  (None, 15, 15, 64)  256         ['conv2d_233[0][0]']
#  Normalization)
#
#  activation_198 (Activation)    (None, 15, 15, 64)   0           ['batch_normalization_232[0][0]']
#
#  conv2d_234 (Conv2D)            (None, 15, 15, 256)  16640       ['activation_198[0][0]']
#
#  conv2d_235 (Conv2D)            (None, 15, 15, 256)  16640       ['max_pooling2d_22[0][0]']
#
#  batch_normalization_233 (Batch  (None, 15, 15, 256)  1024       ['conv2d_234[0][0]']
#  Normalization)
#
#  batch_normalization_234 (Batch  (None, 15, 15, 256)  1024       ['conv2d_235[0][0]']
#  Normalization)
#
#  add_50 (Add)                   (None, 15, 15, 256)  0           ['batch_normalization_233[0][0]',
#                                                                   'batch_normalization_234[0][0]']
#
#  activation_199 (Activation)    (None, 15, 15, 256)  0           ['add_50[0][0]']
#
#  conv2d_236 (Conv2D)            (None, 15, 15, 64)   16448       ['activation_199[0][0]']
#
#  batch_normalization_235 (Batch  (None, 15, 15, 64)  256         ['conv2d_236[0][0]']
#  Normalization)
#
#  activation_200 (Activation)    (None, 15, 15, 64)   0           ['batch_normalization_235[0][0]']
#
#  conv2d_237 (Conv2D)            (None, 15, 15, 64)   36928       ['activation_200[0][0]']
#
#  batch_normalization_236 (Batch  (None, 15, 15, 64)  256         ['conv2d_237[0][0]']
#  Normalization)
#
#  activation_201 (Activation)    (None, 15, 15, 64)   0           ['batch_normalization_236[0][0]']
#
#  conv2d_238 (Conv2D)            (None, 15, 15, 256)  16640       ['activation_201[0][0]']
#
#  batch_normalization_237 (Batch  (None, 15, 15, 256)  1024       ['conv2d_238[0][0]']
#  Normalization)
#
#  add_51 (Add)                   (None, 15, 15, 256)  0           ['batch_normalization_237[0][0]',
#                                                                   'activation_199[0][0]']
#
#  activation_202 (Activation)    (None, 15, 15, 256)  0           ['add_51[0][0]']
#
#  conv2d_239 (Conv2D)            (None, 15, 15, 64)   16448       ['activation_202[0][0]']
#
#  batch_normalization_238 (Batch  (None, 15, 15, 64)  256         ['conv2d_239[0][0]']
#  Normalization)
#
#  activation_203 (Activation)    (None, 15, 15, 64)   0           ['batch_normalization_238[0][0]']
#
#  conv2d_240 (Conv2D)            (None, 15, 15, 64)   36928       ['activation_203[0][0]']
#
#  batch_normalization_239 (Batch  (None, 15, 15, 64)  256         ['conv2d_240[0][0]']
#  Normalization)
#
#  activation_204 (Activation)    (None, 15, 15, 64)   0           ['batch_normalization_239[0][0]']
#
#  conv2d_241 (Conv2D)            (None, 15, 15, 256)  16640       ['activation_204[0][0]']
#
#  batch_normalization_240 (Batch  (None, 15, 15, 256)  1024       ['conv2d_241[0][0]']
#  Normalization)
#
#  add_52 (Add)                   (None, 15, 15, 256)  0           ['batch_normalization_240[0][0]',
#                                                                   'activation_202[0][0]']
#
#  activation_205 (Activation)    (None, 15, 15, 256)  0           ['add_52[0][0]']
#
#  conv2d_242 (Conv2D)            (None, 8, 8, 128)    32896       ['activation_205[0][0]']
#
#  batch_normalization_241 (Batch  (None, 8, 8, 128)   512         ['conv2d_242[0][0]']
#  Normalization)
#
#  activation_206 (Activation)    (None, 8, 8, 128)    0           ['batch_normalization_241[0][0]']
#
#  conv2d_243 (Conv2D)            (None, 8, 8, 128)    147584      ['activation_206[0][0]']
#
#  batch_normalization_242 (Batch  (None, 8, 8, 128)   512         ['conv2d_243[0][0]']
#  Normalization)
#
#  activation_207 (Activation)    (None, 8, 8, 128)    0           ['batch_normalization_242[0][0]']
#
#  conv2d_244 (Conv2D)            (None, 8, 8, 512)    66048       ['activation_207[0][0]']
#
#  conv2d_245 (Conv2D)            (None, 8, 8, 512)    131584      ['activation_205[0][0]']
#
#  batch_normalization_243 (Batch  (None, 8, 8, 512)   2048        ['conv2d_244[0][0]']
#  Normalization)
#
#  batch_normalization_244 (Batch  (None, 8, 8, 512)   2048        ['conv2d_245[0][0]']
#  Normalization)
#
#  add_53 (Add)                   (None, 8, 8, 512)    0           ['batch_normalization_243[0][0]',
#                                                                   'batch_normalization_244[0][0]']
#
#  activation_208 (Activation)    (None, 8, 8, 512)    0           ['add_53[0][0]']
#
#  conv2d_246 (Conv2D)            (None, 8, 8, 128)    65664       ['activation_208[0][0]']
#
#  batch_normalization_245 (Batch  (None, 8, 8, 128)   512         ['conv2d_246[0][0]']
#  Normalization)
#
#  activation_209 (Activation)    (None, 8, 8, 128)    0           ['batch_normalization_245[0][0]']
#
#  conv2d_247 (Conv2D)            (None, 8, 8, 128)    147584      ['activation_209[0][0]']
#
#  batch_normalization_246 (Batch  (None, 8, 8, 128)   512         ['conv2d_247[0][0]']
#  Normalization)
#
#  activation_210 (Activation)    (None, 8, 8, 128)    0           ['batch_normalization_246[0][0]']
#
#  conv2d_248 (Conv2D)            (None, 8, 8, 512)    66048       ['activation_210[0][0]']
#
#  batch_normalization_247 (Batch  (None, 8, 8, 512)   2048        ['conv2d_248[0][0]']
#  Normalization)
#
#  add_54 (Add)                   (None, 8, 8, 512)    0           ['batch_normalization_247[0][0]',
#                                                                   'activation_208[0][0]']
#
#  activation_211 (Activation)    (None, 8, 8, 512)    0           ['add_54[0][0]']
#
#  conv2d_249 (Conv2D)            (None, 8, 8, 128)    65664       ['activation_211[0][0]']
#
#  batch_normalization_248 (Batch  (None, 8, 8, 128)   512         ['conv2d_249[0][0]']
#  Normalization)
#
#  activation_212 (Activation)    (None, 8, 8, 128)    0           ['batch_normalization_248[0][0]']
#
#  conv2d_250 (Conv2D)            (None, 8, 8, 128)    147584      ['activation_212[0][0]']
#
#  batch_normalization_249 (Batch  (None, 8, 8, 128)   512         ['conv2d_250[0][0]']
#  Normalization)
#
#  activation_213 (Activation)    (None, 8, 8, 128)    0           ['batch_normalization_249[0][0]']
#
#  conv2d_251 (Conv2D)            (None, 8, 8, 512)    66048       ['activation_213[0][0]']
#
#  batch_normalization_250 (Batch  (None, 8, 8, 512)   2048        ['conv2d_251[0][0]']
#  Normalization)
#
#  add_55 (Add)                   (None, 8, 8, 512)    0           ['batch_normalization_250[0][0]',
#                                                                   'activation_211[0][0]']
#
#  activation_214 (Activation)    (None, 8, 8, 512)    0           ['add_55[0][0]']
#
#  conv2d_252 (Conv2D)            (None, 8, 8, 128)    65664       ['activation_214[0][0]']
#
#  batch_normalization_251 (Batch  (None, 8, 8, 128)   512         ['conv2d_252[0][0]']
#  Normalization)
#
#  activation_215 (Activation)    (None, 8, 8, 128)    0           ['batch_normalization_251[0][0]']
#
#  conv2d_253 (Conv2D)            (None, 8, 8, 128)    147584      ['activation_215[0][0]']
#
#  batch_normalization_252 (Batch  (None, 8, 8, 128)   512         ['conv2d_253[0][0]']
#  Normalization)
#
#  activation_216 (Activation)    (None, 8, 8, 128)    0           ['batch_normalization_252[0][0]']
#
#  conv2d_254 (Conv2D)            (None, 8, 8, 512)    66048       ['activation_216[0][0]']
#
#  batch_normalization_253 (Batch  (None, 8, 8, 512)   2048        ['conv2d_254[0][0]']
#  Normalization)
#
#  add_56 (Add)                   (None, 8, 8, 512)    0           ['batch_normalization_253[0][0]',
#                                                                   'activation_214[0][0]']
#
#  activation_217 (Activation)    (None, 8, 8, 512)    0           ['add_56[0][0]']
#
#  conv2d_255 (Conv2D)            (None, 4, 4, 256)    131328      ['activation_217[0][0]']
#
#  batch_normalization_254 (Batch  (None, 4, 4, 256)   1024        ['conv2d_255[0][0]']
#  Normalization)
#
#  activation_218 (Activation)    (None, 4, 4, 256)    0           ['batch_normalization_254[0][0]']
#
#  conv2d_256 (Conv2D)            (None, 4, 4, 256)    590080      ['activation_218[0][0]']
#
#  batch_normalization_255 (Batch  (None, 4, 4, 256)   1024        ['conv2d_256[0][0]']
#  Normalization)
#
#  activation_219 (Activation)    (None, 4, 4, 256)    0           ['batch_normalization_255[0][0]']
#
#  conv2d_257 (Conv2D)            (None, 4, 4, 1024)   263168      ['activation_219[0][0]']
#
#  conv2d_258 (Conv2D)            (None, 4, 4, 1024)   525312      ['activation_217[0][0]']
#
#  batch_normalization_256 (Batch  (None, 4, 4, 1024)  4096        ['conv2d_257[0][0]']
#  Normalization)
#
#  batch_normalization_257 (Batch  (None, 4, 4, 1024)  4096        ['conv2d_258[0][0]']
#  Normalization)
#
#  add_57 (Add)                   (None, 4, 4, 1024)   0           ['batch_normalization_256[0][0]',
#                                                                   'batch_normalization_257[0][0]']
#
#  activation_220 (Activation)    (None, 4, 4, 1024)   0           ['add_57[0][0]']
#
#  conv2d_259 (Conv2D)            (None, 4, 4, 256)    262400      ['activation_220[0][0]']
#
#  batch_normalization_258 (Batch  (None, 4, 4, 256)   1024        ['conv2d_259[0][0]']
#  Normalization)
#
#  activation_221 (Activation)    (None, 4, 4, 256)    0           ['batch_normalization_258[0][0]']
#
#  conv2d_260 (Conv2D)            (None, 4, 4, 256)    590080      ['activation_221[0][0]']
#
#  batch_normalization_259 (Batch  (None, 4, 4, 256)   1024        ['conv2d_260[0][0]']
#  Normalization)
#
#  activation_222 (Activation)    (None, 4, 4, 256)    0           ['batch_normalization_259[0][0]']
#
#  conv2d_261 (Conv2D)            (None, 4, 4, 1024)   263168      ['activation_222[0][0]']
#
#  batch_normalization_260 (Batch  (None, 4, 4, 1024)  4096        ['conv2d_261[0][0]']
#  Normalization)
#
#  add_58 (Add)                   (None, 4, 4, 1024)   0           ['batch_normalization_260[0][0]',
#                                                                   'activation_220[0][0]']
#
#  activation_223 (Activation)    (None, 4, 4, 1024)   0           ['add_58[0][0]']
#
#  conv2d_262 (Conv2D)            (None, 4, 4, 256)    262400      ['activation_223[0][0]']
#
#  batch_normalization_261 (Batch  (None, 4, 4, 256)   1024        ['conv2d_262[0][0]']
#  Normalization)
#
#  activation_224 (Activation)    (None, 4, 4, 256)    0           ['batch_normalization_261[0][0]']
#
#  conv2d_263 (Conv2D)            (None, 4, 4, 256)    590080      ['activation_224[0][0]']
#
#  batch_normalization_262 (Batch  (None, 4, 4, 256)   1024        ['conv2d_263[0][0]']
#  Normalization)
#
#  activation_225 (Activation)    (None, 4, 4, 256)    0           ['batch_normalization_262[0][0]']
#
#  conv2d_264 (Conv2D)            (None, 4, 4, 1024)   263168      ['activation_225[0][0]']
#
#  batch_normalization_263 (Batch  (None, 4, 4, 1024)  4096        ['conv2d_264[0][0]']
#  Normalization)
#
#  add_59 (Add)                   (None, 4, 4, 1024)   0           ['batch_normalization_263[0][0]',
#                                                                   'activation_223[0][0]']
#
#  activation_226 (Activation)    (None, 4, 4, 1024)   0           ['add_59[0][0]']
#
#  conv2d_265 (Conv2D)            (None, 4, 4, 256)    262400      ['activation_226[0][0]']
#
#  batch_normalization_264 (Batch  (None, 4, 4, 256)   1024        ['conv2d_265[0][0]']
#  Normalization)
#
#  activation_227 (Activation)    (None, 4, 4, 256)    0           ['batch_normalization_264[0][0]']
#
#  conv2d_266 (Conv2D)            (None, 4, 4, 256)    590080      ['activation_227[0][0]']
#
#  batch_normalization_265 (Batch  (None, 4, 4, 256)   1024        ['conv2d_266[0][0]']
#  Normalization)
#
#  activation_228 (Activation)    (None, 4, 4, 256)    0           ['batch_normalization_265[0][0]']
#
#  conv2d_267 (Conv2D)            (None, 4, 4, 1024)   263168      ['activation_228[0][0]']
#
#  batch_normalization_266 (Batch  (None, 4, 4, 1024)  4096        ['conv2d_267[0][0]']
#  Normalization)
#
#  add_60 (Add)                   (None, 4, 4, 1024)   0           ['batch_normalization_266[0][0]',
#                                                                   'activation_226[0][0]']
#
#  activation_229 (Activation)    (None, 4, 4, 1024)   0           ['add_60[0][0]']
#
#  conv2d_268 (Conv2D)            (None, 4, 4, 256)    262400      ['activation_229[0][0]']
#
#  batch_normalization_267 (Batch  (None, 4, 4, 256)   1024        ['conv2d_268[0][0]']
#  Normalization)
#
#  activation_230 (Activation)    (None, 4, 4, 256)    0           ['batch_normalization_267[0][0]']
#
#  conv2d_269 (Conv2D)            (None, 4, 4, 256)    590080      ['activation_230[0][0]']
#
#  batch_normalization_268 (Batch  (None, 4, 4, 256)   1024        ['conv2d_269[0][0]']
#  Normalization)
#
#  activation_231 (Activation)    (None, 4, 4, 256)    0           ['batch_normalization_268[0][0]']
#
#  conv2d_270 (Conv2D)            (None, 4, 4, 1024)   263168      ['activation_231[0][0]']
#
#  batch_normalization_269 (Batch  (None, 4, 4, 1024)  4096        ['conv2d_270[0][0]']
#  Normalization)
#
#  add_61 (Add)                   (None, 4, 4, 1024)   0           ['batch_normalization_269[0][0]',
#                                                                   'activation_229[0][0]']
#
#  activation_232 (Activation)    (None, 4, 4, 1024)   0           ['add_61[0][0]']
#
#  conv2d_271 (Conv2D)            (None, 4, 4, 256)    262400      ['activation_232[0][0]']
#
#  batch_normalization_270 (Batch  (None, 4, 4, 256)   1024        ['conv2d_271[0][0]']
#  Normalization)
#
#  activation_233 (Activation)    (None, 4, 4, 256)    0           ['batch_normalization_270[0][0]']
#
#  conv2d_272 (Conv2D)            (None, 4, 4, 256)    590080      ['activation_233[0][0]']
#
#  batch_normalization_271 (Batch  (None, 4, 4, 256)   1024        ['conv2d_272[0][0]']
#  Normalization)
#
#  activation_234 (Activation)    (None, 4, 4, 256)    0           ['batch_normalization_271[0][0]']
#
#  conv2d_273 (Conv2D)            (None, 4, 4, 1024)   263168      ['activation_234[0][0]']
#
#  batch_normalization_272 (Batch  (None, 4, 4, 1024)  4096        ['conv2d_273[0][0]']
#  Normalization)
#
#  add_62 (Add)                   (None, 4, 4, 1024)   0           ['batch_normalization_272[0][0]',
#                                                                   'activation_232[0][0]']
#
#  activation_235 (Activation)    (None, 4, 4, 1024)   0           ['add_62[0][0]']
#
#  conv2d_274 (Conv2D)            (None, 2, 2, 512)    524800      ['activation_235[0][0]']
#
#  batch_normalization_273 (Batch  (None, 2, 2, 512)   2048        ['conv2d_274[0][0]']
#  Normalization)
#
#  activation_236 (Activation)    (None, 2, 2, 512)    0           ['batch_normalization_273[0][0]']
#
#  conv2d_275 (Conv2D)            (None, 2, 2, 512)    2359808     ['activation_236[0][0]']
#
#  batch_normalization_274 (Batch  (None, 2, 2, 512)   2048        ['conv2d_275[0][0]']
#  Normalization)
#
#  activation_237 (Activation)    (None, 2, 2, 512)    0           ['batch_normalization_274[0][0]']
#
#  conv2d_276 (Conv2D)            (None, 2, 2, 2048)   1050624     ['activation_237[0][0]']
#
#  conv2d_277 (Conv2D)            (None, 2, 2, 2048)   2099200     ['activation_235[0][0]']
#
#  batch_normalization_275 (Batch  (None, 2, 2, 2048)  8192        ['conv2d_276[0][0]']
#  Normalization)
#
#  batch_normalization_276 (Batch  (None, 2, 2, 2048)  8192        ['conv2d_277[0][0]']
#  Normalization)
#
#  add_63 (Add)                   (None, 2, 2, 2048)   0           ['batch_normalization_275[0][0]',
#                                                                   'batch_normalization_276[0][0]']
#
#  activation_238 (Activation)    (None, 2, 2, 2048)   0           ['add_63[0][0]']
#
#  conv2d_278 (Conv2D)            (None, 2, 2, 512)    1049088     ['activation_238[0][0]']
#
#  batch_normalization_277 (Batch  (None, 2, 2, 512)   2048        ['conv2d_278[0][0]']
#  Normalization)
#
#  activation_239 (Activation)    (None, 2, 2, 512)    0           ['batch_normalization_277[0][0]']
#
#  conv2d_279 (Conv2D)            (None, 2, 2, 512)    2359808     ['activation_239[0][0]']
#
#  batch_normalization_278 (Batch  (None, 2, 2, 512)   2048        ['conv2d_279[0][0]']
#  Normalization)
#
#  activation_240 (Activation)    (None, 2, 2, 512)    0           ['batch_normalization_278[0][0]']
#
#  conv2d_280 (Conv2D)            (None, 2, 2, 2048)   1050624     ['activation_240[0][0]']
#
#  batch_normalization_279 (Batch  (None, 2, 2, 2048)  8192        ['conv2d_280[0][0]']
#  Normalization)
#
#  add_64 (Add)                   (None, 2, 2, 2048)   0           ['batch_normalization_279[0][0]',
#                                                                   'activation_238[0][0]']
#
#  activation_241 (Activation)    (None, 2, 2, 2048)   0           ['add_64[0][0]']
#
#  conv2d_281 (Conv2D)            (None, 2, 2, 512)    1049088     ['activation_241[0][0]']
#
#  batch_normalization_280 (Batch  (None, 2, 2, 512)   2048        ['conv2d_281[0][0]']
#  Normalization)
#
#  activation_242 (Activation)    (None, 2, 2, 512)    0           ['batch_normalization_280[0][0]']
#
#  conv2d_282 (Conv2D)            (None, 2, 2, 512)    2359808     ['activation_242[0][0]']
#
#  batch_normalization_281 (Batch  (None, 2, 2, 512)   2048        ['conv2d_282[0][0]']
#  Normalization)
#
#  activation_243 (Activation)    (None, 2, 2, 512)    0           ['batch_normalization_281[0][0]']
#
#  conv2d_283 (Conv2D)            (None, 2, 2, 2048)   1050624     ['activation_243[0][0]']
#
#  batch_normalization_282 (Batch  (None, 2, 2, 2048)  8192        ['conv2d_283[0][0]']
#  Normalization)
#
#  add_65 (Add)                   (None, 2, 2, 2048)   0           ['batch_normalization_282[0][0]',
#                                                                   'activation_241[0][0]']
#
#  activation_244 (Activation)    (None, 2, 2, 2048)   0           ['add_65[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 1, 1, 2048)  0           ['activation_244[0][0]']
#  oling2D)
#
#  flatten_2 (Flatten)            (None, 2048)         0           ['average_pooling2d_2[0][0]']
#
#  dense_2 (Dense)                (None, 6)            12294       ['flatten_2[0][0]']
#
# ==================================================================================================
# Total params: 23,600,006
# Trainable params: 23,546,886
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
def load_dataset():
  train_dataset = h5py.File("train_signs.h5","r")
  test_dataset = h5py.File("test_signs.h5")

  train_set_x_orig = np.array(train_dataset["train_set_x"][:])
  train_set_y_orig = np.array(train_dataset["train_set_y"][:])
  test_set_x_orig = np.array(test_dataset["test_set_x"][:])       
  test_set_y_orig = np.array(test_dataset["test_set_y"][:])
  
  classes = np.array(test_dataset["list_classes"][:])
  train_set_y_orig = train_set_y_orig.reshape((1, train_set_y_orig.shape[0]))
  test_set_y_orig = test_set_y_orig.reshape((1, test_set_y_orig.shape[0]))

  return train_set_x_orig, train_set_y_orig, test_set_x_orig, test_set_y_orig, classes

# %%
X_train, Y_train, X_test, Y_test, classes = load_dataset()

# %%
def one_hot_encoding(Y,c):
  Y = np.eye(c)[Y.reshape(-1)]
  return Y

# %%
X_train_final = X_train/255.
X_test_final = X_test/255.

Y_train_final = one_hot_encoding(Y_train, c=6)
Y_test_final = one_hot_encoding(Y_test,c=6)
print("X_test : "+ str(X_test_final.shape))
print("X_train : "+str( X_train_final.shape))
print("Y_test : "+ str(Y_test_final.shape))
print("Y_train : "+ str(Y_train_final.shape))
# Out:
# X_test : (120, 64, 64, 3)
# X_train : (1080, 64, 64, 3)
# Y_test : (120, 6)
# Y_train : (1080, 6)

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(X_train_final, Y_train_final, epochs=10,batch_size=32)
# Out:
# Epoch 1/10
# 34/34 [==============================] - 188s 5s/step - loss: 1.6500 - accuracy: 0.4917
# Epoch 2/10
# 34/34 [==============================] - 180s 5s/step - loss: 0.6034 - accuracy: 0.7870
# Epoch 3/10
# 34/34 [==============================] - 177s 5s/step - loss: 0.2236 - accuracy: 0.9213
# Epoch 4/10
# 34/34 [==============================] - 176s 5s/step - loss: 0.4235 - accuracy: 0.8824
# Epoch 5/10
# 34/34 [==============================] - 182s 5s/step - loss: 0.2923 - accuracy: 0.9120
# Epoch 6/10
# 34/34 [==============================] - 178s 5s/step - loss: 0.2488 - accuracy: 0.9407
# Epoch 7/10
# 34/34 [==============================] - 180s 5s/step - loss: 0.2692 - accuracy: 0.9157
# Epoch 8/10
# 34/34 [==============================] - 177s 5s/step - loss: 0.1613 - accuracy: 0.9509
# Epoch 9/10
# 34/34 [==============================] - 173s 5s/step - loss: 0.1458 - accuracy: 0.9593
# Epoch 10/10
# 34/34 [==============================] - 179s 5s/step - loss: 0.0872 - accuracy: 0.9769
